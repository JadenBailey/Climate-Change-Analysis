# %% [markdown]
# # Climate Change Analysis

# %% [markdown]
# ## Introduction

# %% [markdown]
# This is the beginning of my "Solution to Global Warming" project. This notebook will be updated periodically as I gather more information to add and learn more data visualization tools to try out.

# %% [markdown]
# ## Importing and Reading CSV

# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('CO2_levels.csv')

# %%
data
# Out:
#      Year  Month  Decimal Date  Carbon Dioxide (ppm)  \
# 0    1958      1     1958.0411                   NaN
# 1    1958      2     1958.1260                   NaN
# 2    1958      3     1958.2027                315.69
# 3    1958      4     1958.2877                317.45
# 4    1958      5     1958.3699                317.50
# ..    ...    ...           ...                   ...
# 715  2017      8     2017.6219                   NaN
# 716  2017      9     2017.7068                   NaN
# 717  2017     10     2017.7890                   NaN
# 718  2017     11     2017.8740                   NaN
# 719  2017     12     2017.9562                   NaN
#
#      Seasonally Adjusted CO2 (ppm)  Carbon Dioxide Fit (ppm)  \
# 0                              NaN                       NaN
# 1                              NaN                       NaN
# 2                           314.42                    316.18
# 3                           315.15                    317.30
# ...

# %% [markdown]
# ## Section 1: Sampling CO2 Levels

# %% [markdown]
# For this section, I will be sampling the carbon dioxide levels from 1959 and 2016. The reason I chose these two years is because these two years are the earliest and latest years that have full data all throughout the year. 1958 and 2017 contain missing data that I may find later.

# %%
sampleOne = data[data.Year == 1959]
sampleTwo = data[data.Year == 2016]

# %%
sampleOne
# Out:
#     Year  Month  Decimal Date  Carbon Dioxide (ppm)  \
# 12  1959      1     1959.0411                315.58
# 13  1959      2     1959.1260                316.48
# 14  1959      3     1959.2027                316.65
# 15  1959      4     1959.2877                317.72
# 16  1959      5     1959.3699                318.29
# 17  1959      6     1959.4548                318.15
# 18  1959      7     1959.5370                316.54
# 19  1959      8     1959.6219                314.80
# 20  1959      9     1959.7068                313.84
# 21  1959     10     1959.7890                313.34
# 22  1959     11     1959.8740                314.81
# 23  1959     12     1959.9562                315.58
#
#     Seasonally Adjusted CO2 (ppm)  Carbon Dioxide Fit (ppm)  \
# 12                         315.56                    315.60
# 13                         315.88                    316.24
# 14                         315.37                    316.98
# ...

# %%
sampleTwo
# Out:
#      Year  Month  Decimal Date  Carbon Dioxide (ppm)  \
# 696  2016      1     2016.0410                402.65
# 697  2016      2     2016.1257                404.16
# 698  2016      3     2016.2049                404.86
# 699  2016      4     2016.2896                407.57
# 700  2016      5     2016.3716                407.65
# 701  2016      6     2016.4563                407.00
# 702  2016      7     2016.5383                404.50
# 703  2016      8     2016.6230                402.24
# 704  2016      9     2016.7077                401.01
# 705  2016     10     2016.7896                401.50
# 706  2016     11     2016.8743                403.64
# 707  2016     12     2016.9563                404.55
#
#      Seasonally Adjusted CO2 (ppm)  Carbon Dioxide Fit (ppm)  \
# 696                         402.62                    402.82
# 697                         403.42                    403.84
# 698                         403.27                    404.98
# ...

# %%
plt.plot(sampleOne.Month, sampleOne['Carbon Dioxide (ppm)'])
plt.plot(sampleTwo.Month, sampleTwo['Carbon Dioxide (ppm)'])
plt.legend(['1959', '2016'])
plt.xlabel('Month')
plt.ylabel('Carbon Dioxide (ppm)')
plt.show()

# %% [markdown]
# Based off of the chart above, carbon dioxide levels have dramatically increased over the 57 year timespan from below 320 ppm (parts per million) to over 400 ppm and rising.
